# %% [markdown]
# # Physics 1408 Recitation
#
# ## Manuel Pichardo Marcano
# - manuel.pichardo-marcano@ttu.edu

# %% [markdown]
# http://www.glowscript.org/#/user/mmarcano/folder/Public/program/InclinedPlane

# %%
from sympy import *
from sympy.utilities.lambdify import lambdify
t = Symbol('t')
from IPython.display import Image


import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

#Velocity
funcv1 = - 2*t + 2
funcv2 = 2*t - 6
funv = Piecewise( (funcv1, t<2), (funcv2, t>=2))
evalfunc = lambdify(t, funv, modules=['numpy'])

#Position
funpos = funv.integrate()
evalfuncpos = lambdify(t,funpos, modules=['numpy'])

#Acceleration
evalfuncacc = lambdify(t,funv.diff(), modules=['numpy'])

t = np.linspace(0, 3.0, 100)
#Figure
width = 12
height = 12
fig = plt.figure(figsize=(width, height))
ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.gca().axes.xaxis.set_ticklabels([])
plt.gca().axes.yaxis.set_ticklabels([])
plt.xlabel('t')
plt.ylabel('V')


plt.plot(t, evalfunc(t), 'b')
plt.show()

# %%
fig

# %%
s1 = evalfuncpos(t)
s2 = evalfunc(t)
s3 = evalfuncacc(t)

width = 12
height = 12
fig = plt.figure(figsize=(width, height))

ax1 = plt.subplot(311)
plt.plot(t, s1)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax1.get_yticklabels(), visible=False)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax1.spines['left'].set_position('zero')
ax1.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax1.spines['right'].set_color('none')
ax1.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.set_ylim(-10,5)
plt.gca().axes.xaxis.set_ticklabels([])
plt.gca().axes.yaxis.set_ticklabels([])
plt.xlabel('t')
plt.ylabel('x')

# share x only
ax2 = plt.subplot(312, sharex=ax1)
plt.plot(t, s2)
# make these tick labels invisible
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=False)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax2.spines['left'].set_position('zero')
ax2.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax2.spines['right'].set_color('none')
ax2.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.set_ylim(-2, 2.0)
plt.gca().axes.xaxis.set_ticklabels([])
plt.gca().axes.yaxis.set_ticklabels([])
plt.ylabel('V')

# share x and y
ax3 = plt.subplot(313, sharex=ax1)
plt.plot(t, s3)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax3.spines['left'].set_position('zero')
ax3.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.set_ylim(-2, 2.0)
plt.ylabel('a')

plt.gca().axes.xaxis.set_ticklabels([])
plt.gca().axes.yaxis.set_ticklabels([])
plt.show()

# %%
fig

# %% [markdown]
# ## Increase the time

# %%
t = np.linspace(0, 10.0, 100)
s1 = evalfuncpos(t)
s2 = evalfunc(t)
s3 = evalfuncacc(t)

width = 12
height = 12
fig = plt.figure(figsize=(width, height))

ax1 = plt.subplot(311)
plt.plot(t, s1)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax1.get_yticklabels(), visible=False)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax1.spines['left'].set_position('zero')
ax1.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax1.spines['right'].set_color('none')
ax1.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.set_ylim(-10,5)
plt.gca().axes.xaxis.set_ticklabels([])
plt.gca().axes.yaxis.set_ticklabels([])
plt.xlabel('t')
plt.ylabel('x')

# share x only
ax2 = plt.subplot(312, sharex=ax1)
plt.plot(t, s2)
# make these tick labels invisible
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=False)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax2.spines['left'].set_position('zero')
ax2.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax2.spines['right'].set_color('none')
ax2.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.set_ylim(-2, 2.0)
plt.gca().axes.xaxis.set_ticklabels([])
plt.gca().axes.yaxis.set_ticklabels([])
plt.ylabel('V')

# share x and y
ax3 = plt.subplot(313, sharex=ax1)
plt.plot(t, s3)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax3.spines['left'].set_position('zero')
ax3.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax3.spines['right'].set_color('none')
ax3.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.set_ylim(-2, 2.0)
plt.ylabel('a')

plt.gca().axes.xaxis.set_ticklabels([])
plt.gca().axes.yaxis.set_ticklabels([])
plt.show()

# %%
fig

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
from matplotlib import animation, rc
rc('animation', html='html5')


t = np.linspace(0, 10.0, 1000)
#------------------------------------------------------------
# set up figure and animation
fig = plt.figure()
ax = fig.add_subplot(111, aspect='equal', autoscale_on=False,
                     xlim=(-10,50), ylim=(-1, 1))
ax.grid()

line, = ax.plot([], [], 'o-', lw=2)
time_text = ax.text(0.02, 0.95, '', transform=ax.transAxes)

def init():
    """initialize animation"""
    line.set_data([], [])
    time_text.set_text('')
    ii = 0
    return line, time_text

def animate(i):
    """perform animation step"""
    global  dt
    ii = i + 1
    x =(evalfuncpos(t[ii])  , 0  )   
    line.set_data(x)
    time_text.set_text('time = %.1f' % t[ii])
    return line, time_text

# choose the interval based on dt and the time to animate one step
from time import time
t0 = time()
animate(0)
t1 = time()
dt = t[1]
interval = 1000 * dt - (t1 - t0)
frames = len(t)-1

ani = animation.FuncAnimation(fig, animate, frames=frames,
                              interval=interval, blit=True, init_func=init)
# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is

# %%
ani
# Out:
# <video width="432.0" height="288.0" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
from matplotlib import animation, rc
rc('animation', html='html5')


#Velocity
t = Symbol('t')
funcv1 = - 2*t + 2
funcv2 = 2*t - 6
funv = Piecewise( (funcv1, t<2), (funcv2, t>=2))
evalfunc = lambdify(t, funv, modules=['numpy'])

#Position
funpos = funv.integrate()
evalfuncpos = lambdify(t,funpos, modules=['numpy'])

#Acceleration
evalfuncacc = lambdify(t,funv.diff(), modules=['numpy'])
t = np.linspace(0,30.0, 300)

T = 10
timee = 3 * T
slow_motion_factor = 1
fps = 50
interval = 1 / fps

#------------------------------------------------------------
# set up figure and animation
fig = plt.figure()
ax = fig.add_subplot(111, aspect='equal', autoscale_on=False,
                     xlim=(-10,20), ylim=(-1, 1))
ax.grid()

line, = ax.plot([], [], 'o-', lw=2)
time_text = ax.text(0.02, 0.95, '', transform=ax.transAxes)

def init():
    """initialize animation"""
    line.set_data([], [])
    time_text.set_text('')
    ii = 0
    return line, time_text

def animate(i):
    """perform animation step"""
    global  dt
    ii = i + 1
    x =(evalfuncpos(t[ii])  , 0  )   
    line.set_data(x)
    time_text.set_text('time = %.1f' % t[ii])
    return line, time_text

# choose the interval based on dt and the time to animate one step
from time import time
t0 = time()
animate(0)
t1 = time()
dt = t[1]
#interval = 1000 * dt - (t1 - t0)
interval = 10
frames = len(t)-1

ani = animation.FuncAnimation(fig, animate, frames=frames,
                              interval=interval, blit=True, init_func=init)
# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is

# %%
ani
# Out:
# <video width="432.0" height="288.0" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
from moviepy.video.io.bindings import mplfig_to_npimage
import moviepy.editor as mpy

# DRAW A FIGURE WITH MATPLOTLIB

duration = 2

fig_mpl, ax = plt.subplots(1,figsize=(5,3), facecolor='white')
xx = np.linspace(-2,2,200) # the x vector
zz = lambda d: np.sinc(xx**2)+np.sin(xx+d) # the (changing) z vector
ax.set_title("Elevation in y=0")
ax.set_ylim(-1.5,2.5)
line, = ax.plot(xx, zz(0), lw=3)

# ANIMATE WITH MOVIEPY (UPDATE THE CURVE FOR EACH t). MAKE A GIF.

def make_frame_mpl(t):
    line.set_ydata( zz(2*np.pi*t/duration))  # <= Update the curve
    return mplfig_to_npimage(fig_mpl) # RGB image of the figure

animation =mpy.VideoClip(make_frame_mpl, duration=duration)
animation.write_gif("sinc_mpl.gif", fps=20)
# Out:
# [MoviePy] Building file sinc_mpl.gif with imageio
#  98%|█████████▊| 40/41 [00:00<00:00, 52.93it/s]

# %%
import gizeh
import moviepy.editor as mpy

W,H = 128,128 # width, height, in pixels
duration = 2 # duration of the clip, in seconds

def make_frame(t):
    surface = gizeh.Surface(W,H)
    radius = W*(1+ (t*(duration-t))**2 )/6
    circle = gizeh.circle(radius, xy = (W/2,H/2), fill=(1,0,0))
    circle.draw(surface)
    return surface.get_npimage()

clip = mpy.VideoClip(make_frame, duration=duration)
clip.write_gif("circle.gif",fps=15, opt="OptimizePlus", fuzz=10)
# Out:
# [MoviePy] Building file circle.gif with imageio
#  97%|█████████▋| 30/31 [00:00<00:00, 725.64it/s]

# %%
import numpy as np
import gizeh as gz
import moviepy.editor as mpy

W,H = 1000,75
D = 10
r = 10 # radius of the ball
DJ, HJ = 50, 35 # distance and height of the jumps
ground = 0.75*H # y-coordinate of the ground

gradient = gz.ColorGradient(type="radial",
                stops_colors = [(0,(1,0,0)),(1,(0.1,0,0))],
                xy1=[0.3,-0.3], xy2=[0,0], xy3 = [0,1.4])


def make_frame(t):
    surface = gz.Surface(W,H, bg_color=(1,1,1))
    x = (-W/3)+(5*W/3)*(t/D)
    y = 20
    ball = gz.circle(r=1, fill=gradient).scale(r).translate((x,y))
    ball.draw(surface)
    return surface.get_npimage()

clip = mpy.VideoClip(make_frame, duration=D)
clip.write_gif("bouncingball.gif",fps=25, opt="OptimizePlus")
# Out:
# [MoviePy] Building file bouncingball.gif with imageio
# 100%|█████████▉| 250/251 [00:00<00:00, 338.89it/s]

# %%
Image('bouncingball.gif', format='png')

# %%
funpos

# %% [markdown]
# # Week 3

# %%
"""
A simple example of an animated plot... In 3D!
"""
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation

def Gen_RandLine(length, dims=2) :
    """
    Create a line using a random walk algorithm

    length is the number of points for the line.
    dims is the number of dimensions the line has.
    """
    lineData = np.empty((dims, length))
    lineData[:, 0] = np.random.rand(dims)
    for index in range(1, length) :
        # scaling the random numbers by 0.1 so
        # movement is small compared to position.
        # subtraction by 0.5 is to change the range to [-0.5, 0.5]
        # to allow a line to move backwards.
        step = ((np.random.rand(dims) - 0.5) * 0.1)
        lineData[:, index] = lineData[:, index-1] + step

    return lineData

def update_lines(num, dataLines, lines) :
    for line, data in zip(lines, dataLines) :
        # NOTE: there is no .set_data() for 3 dim data...
        line.set_data(data[0:2, :num])
        line.set_3d_properties(data[2,:num])
    return lines

# Attaching 3D axis to the figure
fig = plt.figure()
ax = p3.Axes3D(fig)

# Fifty lines of random 3-D lines
data = [Gen_RandLine(25, 3) for index in range(50)]

# Creating fifty line objects.
# NOTE: Can't pass empty arrays into 3d version of plot()
lines = [ax.plot(dat[0, 0:1], dat[1, 0:1], dat[2, 0:1])[0] for dat in data]

# Setting the axes properties
ax.set_xlim3d([0.0, 1.0])
ax.set_xlabel('X')

ax.set_ylim3d([0.0, 1.0])
ax.set_ylabel('Y')

ax.set_zlim3d([0.0, 1.0])
ax.set_zlabel('Z')

ax.set_title('3D Test')

# Creating the Animation object
line_ani = animation.FuncAnimation(fig, update_lines, 25, fargs=(data, lines),
                              interval=50, blit=False)

plt.legend()
plt.show()

# %%
import numpy as np
import gizeh as gz
import moviepy.editor as mpy
from sympy import *

W,H = 1000,200
D = 10
r = 10 # radius of the ball
DJ, HJ = 50, 35 # distance and height of the jumps
ground = 0.75*H # y-coordinate of the ground
t = Symbol('t')
m = Symbol('m')
F = 100 #N
ma = 20
mb = 10
mc = 5
#Acceleration
a = Function('a')('m','t')
a= F/m
evalfunc = lambdify([t,m], a, modules=['numpy'])
#Velocity
funvel = integrate(a,t)
evalfuncvel = lambdify([t,m],funvel, modules=['numpy'])
#Position
evalfuncpos = lambdify([t,m],integrate(funvel,t), modules=['numpy'])


gradient = gz.ColorGradient(type="radial",
                stops_colors = [(0,(1,0,0)),(1,(0.1,0,0))],
                xy1=[0.3,-0.3], xy2=[0,0], xy3 = [0,1.4])

def make_frame(t):
    #Velocityo
    surface = gz.Surface(W,H, bg_color=(1,1,1))
    x = evalfuncpos(t,ma)
    y = 30
    x2 = evalfuncpos(t,mb)
    y2 = 90
    x3 = evalfuncpos(t,mc)
    y3 = 130
    ball = gz.circle(r=3, fill=gradient).scale(r).translate((x,y))
    ball2 = gz.circle(r=2, fill=gradient).scale(r).translate((x2,y2))
    ball3 = gz.circle(r=1, fill=gradient).scale(r).translate((x3,y3))
    ball.draw(surface)
    ball2.draw(surface)
    ball3.draw(surface)
    return surface.get_npimage()

clip = mpy.VideoClip(make_frame, duration=D)
clip.write_gif("bouncingball.gif",fps=25, opt="OptimizePlus")
# Out:
# [MoviePy] Building file bouncingball.gif with imageio
# 100%|█████████▉| 250/251 [00:01<00:00, 151.14it/s]

# %%
Image('bouncingball.gif', format='png')

# %%
evalfunc = lambdify([t,m], a, modules=['numpy'])

# %%
evalfuncpos(2,2)
# Out:
# 10.0

# %%
from ivisual import *

#create scene
scene = canvas(title='Cartesian Coordinate System')

sphere()
# Out:
# <div id="scene1"><div id="glowscript" class="glowscript"></div></div>
